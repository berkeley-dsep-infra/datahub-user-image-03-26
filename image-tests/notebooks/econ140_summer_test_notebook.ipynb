# %%
library(googlesheets4)
gs4_deauth()

# %%
sheet_url = "https://docs.google.com/spreadsheets/d/1uVN0_Wgz30nnng7Bt7H7xfYIqKL_g6W9ifLbF7wMK04/edit?usp=sharing"
ah_heights <- read_sheet(sheet_url,
                         range = "A1:F5069")
# Out:
# ✔ Reading from addhealth_height_w4_nomiss.
#
# ✔ Range A1:F5069.

# %%
head(ah_heights)
dimensions = dim(ah_heights)
n = dimensions[1]
n
# Out:
#   aid      num r4sex r4height r4heightbio diff
# 1 57101310 1   2     71       70.86618     0.1338196
# 2 57103869 2   1     81       79.52760     1.4723969
# 3 57109625 3   1     64       63.38586     0.6141396
# 4 57111071 4   1     69       69.68507    -0.6850739
# 5 57113943 5   1     74       73.03153     0.9684677
# 6 57117542 6   1     74       72.83469     1.1653137
# [1] 5068
